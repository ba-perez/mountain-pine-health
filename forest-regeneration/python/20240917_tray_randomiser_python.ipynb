# %%
### Randomise seed and control placement in propagation trays -- Python version
### Coder: Barbara Araujo
### Date: 2024.09.17.

# %%
# randomiser
import random
random.seed(69)

# output design
from rich.console import Console
from rich.table import Table

# export outputs
import pandas as pd

# %%
# Control station

# Test version ON/OFF (will only produce one plate)
TEST = False

# %%
# define objects and their counts
objects = ['E']*3 + ['P. abies']*5 + ['P. cembra']*5 + ['A. pseudoplatanus']*5 + ['S. aucuparia']*5
num_plates = 72
plate_size = (4, 6)

# fix position of logger 'L' (row, col).
position_L = (2, 2)

# %%
# generate plate with random positions
def generate_plate():
    # empty plate
    plate = [['' for _ in range(plate_size[1])] for _ in range(plate_size[0])]
    
    # fix position of 'L'
    plate[position_L[0]][position_L[1]] = 'L'
     
    # randomly shuffle and assign other positions
    available_positions = [(r, c) for r in range(plate_size[0]) for c in range(plate_size[1]) if (r, c) != position_L]
    random.shuffle(available_positions)
    for obj, (r, c) in zip(objects, available_positions):
        plate[r][c] = obj

    return plate

# %%
# display plate
def display_plate(plate, plate_number):
    console = Console()
    table = Table(show_header=False, show_lines=True, border_style='black')

    for _ in range(plate_size[1]):
        table.add_column(justify="center")

    # dictionary for all objects
    symbol_map = {
        'E': '[black]leer[/black]',  # E stays as E
        'L': '[black]logger[/black]',  # L stays as L
        'P. abies': '[bright_blue]P. abi[/bright_blue]',  # P. abies is mapped to 'A'
        'P. cembra': '[green4]P. cem[/green4]',  # P. cembra is mapped to 'C'
        'A. pseudoplatanus': '[bright_red]A. pse[/bright_red]',  # A. pseudoplatanus is mapped to 'P'
        'S. aucuparia': '[gold3]S. auc[/gold3]'  # S. aucuparia is mapped to 'S'
    }

    # populate and print table
    for row in plate:
        table.add_row(*[symbol_map[cell] for cell in row])

    console.print(f"Plate {plate_number}")
    console.print(table)

# %%
# Generate one plate for testing
if TEST:

    test_plate = generate_plate()
    display_plate(test_plate, "test")

# %%
# Generate all 72 plates
if not TEST:

    plates = [generate_plate() for _ in range(num_plates)]
    for i, plate in enumerate(plates, start=1):
        display_plate(plate, i)
# Out:
# Plate 1
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ S. auc │ S. auc │ S. auc │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ P. cem │ P. cem │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ logger │ P. cem │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ P. cem │ P. abi │ S. auc │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 2
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ A. pse │  leer  │ A. pse │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ P. abi │ S. auc │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ logger │ P. cem │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ P. cem │ P. cem │ S. auc │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 3
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. cem │ S. auc │ P. abi │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ S. auc │ P. abi │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ logger │  leer  │ S. auc │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ P. cem │ A. pse │ A. pse │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 4
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. cem │  leer  │ P. abi │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ A. pse │ P. cem │ P. cem │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ logger │ P. abi │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ A. pse │ S. auc │ P. abi │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 5
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. abi │ P. abi │ S. auc │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │  leer  │  leer  │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ logger │ S. auc │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ P. cem │ P. cem │ A. pse │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 6
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. cem │ A. pse │ A. pse │ P. abi │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ P. cem │  leer  │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ logger │ S. auc │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ A. pse │ P. cem │ P. abi │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 7
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ A. pse │ P. cem │ P. abi │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ S. auc │ P. abi │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ logger │ P. cem │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ S. auc │  leer  │ A. pse │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 8
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │  leer  │  leer  │ S. auc │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ A. pse │ S. auc │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ logger │ P. cem │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ P. cem │ P. abi │ A. pse │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 9
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ S. auc │ P. cem │ P. abi │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │  leer  │ P. abi │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ logger │ A. pse │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ P. cem │  leer  │ A. pse │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 10
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │  leer  │ P. abi │ A. pse │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ S. auc │ P. abi │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ logger │  leer  │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ P. abi │ A. pse │ A. pse │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 11
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. abi │ P. abi │ S. auc │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ P. cem │ S. auc │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ logger │ P. abi │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ A. pse │ P. abi │ P. cem │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 12
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. cem │ P. cem │ A. pse │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ S. auc │ S. auc │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ logger │ S. auc │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │  leer  │ P. cem │ P. abi │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 13
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ S. auc │ P. abi │ A. pse │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ A. pse │ S. auc │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ logger │ S. auc │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │  leer  │ S. auc │ P. cem │  leer  │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 14
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. cem │ S. auc │ A. pse │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ S. auc │ P. abi │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ logger │ S. auc │ P. cem │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ P. cem │ S. auc │  leer  │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 15
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. cem │ A. pse │  leer  │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ P. cem │ P. abi │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ logger │ A. pse │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │ P. abi │ P. abi │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 16
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ S. auc │ S. auc │ P. abi │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ S. auc │ P. abi │ S. auc │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ logger │  leer  │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ P. cem │ S. auc │ P. cem │  leer  │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 17
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. cem │  leer  │ P. abi │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ A. pse │ P. abi │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ logger │ A. pse │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ A. pse │  leer  │ S. auc │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 18
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. cem │ S. auc │ S. auc │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │  leer  │ P. abi │ A. pse │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ logger │ A. pse │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ A. pse │ P. cem │ P. cem │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 19
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. abi │ P. cem │ A. pse │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. abi │ A. pse │ A. pse │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ logger │ P. cem │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ P. cem │  leer  │ P. cem │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 20
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. abi │  leer  │ P. cem │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ S. auc │ A. pse │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. abi │ logger │ S. auc │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ S. auc │ S. auc │ S. auc │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 21
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. cem │ P. abi │ P. cem │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ P. abi │  leer  │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ logger │  leer  │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │ S. auc │ A. pse │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 22
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │  leer  │ S. auc │ P. cem │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ P. cem │ A. pse │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ logger │ S. auc │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ P. abi │ P. cem │  leer  │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 23
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ P. cem │  leer  │ P. cem │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ A. pse │ S. auc │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │  leer  │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ P. abi │ S. auc │ P. cem │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 24
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │  leer  │ S. auc │ A. pse │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ P. abi │ P. cem │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ P. abi │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ S. auc │ P. cem │ S. auc │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 25
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ S. auc │ S. auc │ P. cem │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. abi │ S. auc │  leer  │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ P. abi │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │  leer  │ A. pse │ P. cem │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 26
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │  leer  │ S. auc │ P. abi │ S. auc │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ S. auc │ A. pse │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ logger │ P. abi │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ P. cem │ P. abi │ A. pse │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 27
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ S. auc │ P. cem │ P. cem │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ P. cem │  leer  │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ S. auc │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ P. abi │  leer  │ P. abi │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 28
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ A. pse │ P. abi │ P. cem │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ P. cem │ S. auc │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ logger │ P. cem │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ A. pse │ P. abi │ S. auc │  leer  │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 29
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ A. pse │ S. auc │ P. cem │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ A. pse │ A. pse │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ logger │  leer  │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ S. auc │ P. abi │ A. pse │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 30
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ P. cem │ P. abi │ P. abi │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ A. pse │ S. auc │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ logger │ S. auc │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │ S. auc │  leer  │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 31
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ P. abi │ P. cem │ P. abi │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ P. cem │ P. abi │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ logger │ S. auc │ P. abi │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │  leer  │ P. cem │ P. abi │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 32
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │  leer  │ P. abi │ P. cem │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ P. abi │ P. abi │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │  leer  │ logger │ S. auc │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ P. cem │ A. pse │ A. pse │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 33
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ P. abi │ S. auc │ P. cem │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ S. auc │ A. pse │  leer  │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ logger │ S. auc │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ A. pse │ P. cem │ P. cem │  leer  │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 34
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ A. pse │ A. pse │ P. abi │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ P. cem │ A. pse │ S. auc │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ logger │  leer  │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ P. abi │ S. auc │ P. cem │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 35
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │  leer  │ S. auc │ P. cem │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ A. pse │ P. abi │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ logger │ S. auc │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ S. auc │ P. abi │ P. abi │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 36
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. abi │ P. abi │  leer  │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ P. cem │ S. auc │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ logger │  leer  │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ S. auc │ S. auc │ S. auc │ A. pse │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 37
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ S. auc │ A. pse │ P. cem │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. abi │ P. cem │  leer  │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ S. auc │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ S. auc │ A. pse │ S. auc │ P. cem │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 38
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. cem │  leer  │ A. pse │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ A. pse │ P. cem │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ logger │  leer  │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ P. abi │ S. auc │ S. auc │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 39
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ A. pse │ A. pse │ S. auc │ P. cem │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │  leer  │ P. abi │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ logger │ S. auc │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ A. pse │ S. auc │ P. cem │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 40
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ S. auc │ P. cem │ S. auc │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │  leer  │ P. abi │ S. auc │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ S. auc │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ A. pse │ P. cem │ P. abi │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 41
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ P. cem │ S. auc │ P. abi │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ P. cem │ A. pse │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ logger │ S. auc │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ P. cem │  leer  │  leer  │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 42
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ A. pse │ S. auc │ A. pse │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │  leer  │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │  leer  │ logger │ P. abi │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ A. pse │ P. abi │ A. pse │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 43
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ A. pse │ P. abi │ P. abi │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ P. abi │  leer  │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ logger │ P. cem │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ P. abi │  leer  │ S. auc │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 44
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ S. auc │ P. abi │ P. abi │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ S. auc │  leer  │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ logger │ P. cem │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ P. abi │ P. cem │ S. auc │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 45
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. abi │ S. auc │ P. abi │ P. cem │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ A. pse │ P. cem │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ logger │ A. pse │ P. abi │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ P. abi │  leer  │ S. auc │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 46
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ A. pse │ S. auc │  leer  │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ S. auc │ P. cem │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │  leer  │ logger │ P. cem │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ A. pse │ P. cem │ P. cem │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 47
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. cem │ S. auc │ P. abi │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ A. pse │ A. pse │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ logger │  leer  │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ A. pse │ P. cem │ P. abi │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 48
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ A. pse │ P. abi │ S. auc │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ S. auc │  leer  │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ logger │  leer  │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ S. auc │ P. cem │ P. cem │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 49
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. abi │  leer  │ A. pse │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │ P. abi │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ S. auc │ logger │ A. pse │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ P. cem │ P. cem │ P. cem │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 50
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. abi │ A. pse │ P. abi │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ A. pse │ P. cem │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ logger │ S. auc │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ P. abi │ A. pse │ S. auc │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 51
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │  leer  │ A. pse │ P. abi │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │  leer  │ A. pse │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. abi │ logger │ P. abi │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ A. pse │ P. cem │  leer  │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 52
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │  leer  │ P. cem │ S. auc │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ S. auc │  leer  │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ logger │ P. cem │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ P. cem │ A. pse │ S. auc │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 53
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ A. pse │ P. abi │ A. pse │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │  leer  │ P. abi │ P. cem │ P. cem │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │ logger │ S. auc │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │  leer  │ A. pse │  leer  │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 54
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. abi │ A. pse │ A. pse │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │  leer  │ P. abi │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ logger │ A. pse │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │  leer  │ P. cem │  leer  │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 55
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. cem │  leer  │ S. auc │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ S. auc │ A. pse │ P. cem │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ logger │  leer  │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │ S. auc │ P. abi │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 56
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. abi │  leer  │ A. pse │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ P. cem │ S. auc │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ logger │ A. pse │ A. pse │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ P. cem │ P. abi │  leer  │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 57
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. abi │ P. abi │ P. abi │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ P. cem │ A. pse │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ P. cem │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ P. cem │ S. auc │ S. auc │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 58
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. abi │  leer  │ A. pse │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ P. abi │  leer  │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ A. pse │ P. abi │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ P. cem │ S. auc │ P. abi │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 59
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ P. abi │ S. auc │ P. cem │ P. abi │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ P. abi │ S. auc │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ logger │ A. pse │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. abi │  leer  │  leer  │ P. cem │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 60
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. abi │ P. cem │ P. abi │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ P. abi │  leer  │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ S. auc │ logger │ S. auc │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. cem │ P. abi │ A. pse │ A. pse │ P. cem │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 61
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ A. pse │ S. auc │ P. abi │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ P. cem │ A. pse │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ logger │ P. cem │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ S. auc │  leer  │  leer  │ P. abi │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 62
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ S. auc │ P. abi │ A. pse │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ A. pse │ P. abi │ P. cem │ P. cem │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ logger │ P. abi │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ A. pse │ A. pse │ A. pse │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 63
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ P. abi │ P. cem │ P. cem │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ S. auc │ A. pse │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ S. auc │ logger │ P. abi │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ A. pse │  leer  │  leer  │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 64
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. abi │ A. pse │ A. pse │ P. cem │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ A. pse │ P. cem │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ logger │ P. cem │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ A. pse │ A. pse │ P. abi │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 65
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ A. pse │ A. pse │ P. abi │ S. auc │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ S. auc │ P. cem │ S. auc │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ logger │  leer  │ A. pse │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ S. auc │ P. cem │ S. auc │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 66
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ S. auc │ S. auc │ P. cem │  leer  │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. cem │ P. cem │ P. abi │  leer  │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ logger │ P. cem │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ A. pse │ P. abi │ S. auc │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 67
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │ P. abi │ S. auc │ A. pse │ P. abi │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ P. abi │ P. abi │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ logger │ P. cem │ S. auc │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │  leer  │ P. cem │ P. cem │ S. auc │  leer  │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 68
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ P. cem │ A. pse │ A. pse │ A. pse │ S. auc │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ S. auc │ P. abi │ S. auc │  leer  │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ logger │ P. abi │ P. cem │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ A. pse │ S. auc │ P. cem │ P. cem │  leer  │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 69
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ S. auc │ P. abi │ P. abi │  leer  │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ S. auc │ P. cem │ S. auc │ S. auc │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ P. abi │ logger │ P. cem │ P. cem │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ A. pse │ P. cem │ P. abi │ A. pse │ A. pse │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 70
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │  leer  │ P. abi │ S. auc │ P. cem │ S. auc │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ A. pse │ S. auc │ S. auc │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ logger │ A. pse │  leer  │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. cem │ P. abi │ A. pse │ P. cem │ P. abi │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 71
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ S. auc │  leer  │ P. cem │ S. auc │ A. pse │ P. cem │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ A. pse │ A. pse │ P. abi │ A. pse │ S. auc │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ P. abi │ P. cem │ logger │ P. abi │ A. pse │  leer  │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. abi │ P. abi │ P. cem │ P. cem │ S. auc │
# └────────┴────────┴────────┴────────┴────────┴────────┘
# Plate 72
# ┌────────┬────────┬────────┬────────┬────────┬────────┐
# │ A. pse │ S. auc │  leer  │ S. auc │ P. cem │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ A. pse │ S. auc │ P. abi │ S. auc │ P. abi │ P. abi │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │ S. auc │ P. cem │ logger │  leer  │ P. abi │ A. pse │
# ├────────┼────────┼────────┼────────┼────────┼────────┤
# │  leer  │ P. cem │ P. cem │ A. pse │ P. cem │ P. abi │
# └────────┴────────┴────────┴────────┴────────┴────────┘
